# %% [markdown]
# MODEL no.1:
# Simple Regression Model

# %% [markdown]
# Initialize Notebook

# %%
import datetime
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
# Out:
# Notebook last run (end-to-end): 2025-09-12 01:26:43.874523

# %% [markdown]
# 1. Import libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# 2. Generate a dataset

# %%
X = np.array([-15.0, -10.0, -5.0, 0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 30.0])
y = np.array([-30.0, -20.0, -10.0, 0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0])

# %% [markdown]
# 2.1 Reshape dataset made from .array([]) for tensorflow

# %%
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# %% [markdown]
# 2.1 dataset Visualization using matplotlib

# %%
plt.scatter(X, y, color="blue")
plt.title("Custom Data for Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Building the model

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

# %% [markdown]
# 4. Compile the model

# %%
model.compile(
    loss=tf.keras.losses.MeanAbsoluteError(),
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    metrics=["mae"]
)

# %% [markdown]
# 5. Training the model

# %%
history = model.fit(
    X, y,
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 18.4912 - mae: 18.4912
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.3089 - mae: 18.3089
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.1266 - mae: 18.1266
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.9443 - mae: 17.9443
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.7620 - mae: 17.7620
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.5797 - mae: 17.5797
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.3975 - mae: 17.3975
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.2152 - mae: 17.2152
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.0329 - mae: 17.0329
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.8506 - mae: 16.8506
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.6683 - mae: 16.6683
# Epoch 12/100
# ...

# %% [markdown]
# 5.1 Visualize training data loss

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label="Training Loss (MSE)")
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 6. Generate predictions

# %%
model.predict(np.array([35.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# array([[69.32983]], dtype=float32)

# %% [markdown]
# 6.1 Visualize predictions

# %%
X_test = np.linspace(-20, 40, 100)
y_pred = model.predict(X_test)

plt.scatter(X, y, label="Original Data")
plt.plot(X_test, y_pred, color="red", label="Model Predictions")
plt.legend()
plt.title("Model Fit on Custom Dataset")
plt.xlabel("X")
plt.ylabel("Predicted y")
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
